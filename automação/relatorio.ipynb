# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

#navegando até o drive
pyautogui.hotkey('ctrl', 't')
time.sleep(2)
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

#esperar a página carregar
time.sleep(7)

#navegar até o arquivo e baixar
pyautogui.click(x=376, y=296, clicks=2)
time.sleep(5)
pyautogui.click(x=376, y=296)
pyautogui.click(x=1224, y=191)
time.sleep(3)
pyautogui.click(x=971, y=622)

#esperando o arquivo ser baixado
time.sleep(20)

# %%
#importando a tabela
import pandas as pd
tabela = pd.read_excel(r'C:\Users\Fabio\Downloads\Vendas - Dez.xlsx')

#calculando os totais
quantidade = tabela['Quantidade'].sum()
faturamento = tabela['Valor Final'].sum()

display(tabela)
print(f'Quantidade total: {quantidade:,}\nValor Final: R${faturamento:,.2f}')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#enviando para o email

pyautogui.hotkey('ctrl', 't')
time.sleep(2)
pyperclip.copy('https://mail.google.com/mail/u/0/#inbox')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

#esperar a página carregar
time.sleep(7)

#abrindo novo email
pyautogui.click(x=74, y=202)
time.sleep(15)
pyautogui.write('fabio_9.9@hotmail.com')
pyautogui.hotkey('tab')
pyautogui.hotkey('tab')
pyperclip.copy('Relatório de vendas')
pyautogui.hotkey('ctrl', 'v')
pyautogui.hotkey('tab')

texto = f"""
Prezados, bom dia

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs
Fabio Lucas"""
pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')

#enviando email
pyautogui.hotkey('ctrl', 'enter')

# %%
#Pegando a posição do mouse
#import time
#time.sleep(5)
#pyautogui.position()
# Out:
# Point(x=74, y=202)
